# %%
import matplotlib.pyplot as plt

# %%
test_1 = [24.9235, 22.3242, 25.0109, 34.7313, 35.3429, 31.0398]
test_2 = [28.6863, 34.2270, 46.5594, 46.3807, 45.7551, 32.7971]
test_3 = [25.9150, 28.0992, 31.9953, 44.3329, 41.1452, 33.4711]
test_4 = [33.0652, 36.2824, 44.5040, 46.5594, 44.4147, 32.7971]
test_5 = [34.2270, 33.6014, 46.6488, 47.2744, 45.1296, 32.7971]
test_6 = [33.3333, 33.7802, 45.3977, 46.6488, 44.6828, 32.7971]
x = ['KNeighborsClassifier', 'DecisionTreeClassifier', 'RandomForestClassifier', 'LinearDiscriminantAnalysis', 'Pipeline', 'SVC']

# %%
plt.figure(figsize=(15,5))
plt.plot (x, test_1, label = 'Test 1')
plt.plot (x, test_2, label = 'Test 2')
plt.plot (x, test_3, label = 'Test 3')
plt.plot (x, test_4, label = 'Test 4')
plt.plot (x, test_5, label = 'Test 5')
plt.plot (x, test_6, label = 'Test 6')
plt.xlabel('Clasificador')
plt.ylabel('Accuracy %')
plt.legend()
plt.show()
